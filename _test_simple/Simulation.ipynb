# %% [markdown]
# # Articulation-Acoustics Mapping

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from tools import *

# %%
interactive_plot = interactive(pca_forward_plot, 
                               pc1=(-5.0,5.0,0.5), pc2=(-5.0,5.0,0.5), pc3=(-5.0,5.0,0.5),continuous_update=False)
output = interactive_plot.children[-1]
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='pc1', max=5.0, min=-5.0, step=0.5), FloatSlider(value=0.0, description='pc2', max=5.0, min=-5.0, step=0.5), FloatSlider(value=0.0, description='pc3', max=5.0, min=-5.0, step=0.5), Output()), _dom_classes=('widget-interact',))

# %%
# !nbinteract init
# !nbinteract Simulation.ipynb
